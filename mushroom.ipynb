# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
df['class'] = df['class'].map({"e": "edible", "p": "poisonous"})
df.iloc[:,:8]
# Out:
#           class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     poisonous         x           s         n       t    p               f
# 1        edible         x           s         y       t    a               f
# 2        edible         b           s         w       t    l               f
# 3     poisonous         x           y         w       t    p               f
# 4        edible         x           s         g       f    n               f
# ...         ...       ...         ...       ...     ...  ...             ...
# 8119     edible         k           s         n       f    n               a
# 8120     edible         x           s         n       f    n               a
# 8121     edible         f           s         n       f    n               a
# 8122  poisonous         k           y         n       f    y               f
# 8123     edible         x           s         n       f    n               a
#
#      gill-spacing
# 0               c
# 1               c
# 2               c
# 3               c
# 4               w
# ...           ...
# 8119            c
# 8120            c
# 8121            c
# 8122            c
# 8123            c
#
# [8124 rows x 8 columns]

# %%
sns.countplot(df['class'],label='count')

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
df['cap-shape']=lb.fit_transform(df['cap-shape'])
df['cap-surface']=lb.fit_transform(df['cap-surface'])
df['cap-color']=lb.fit_transform(df['cap-color'])
df['bruises']=lb.fit_transform(df['bruises'])
df['odor']=lb.fit_transform(df['odor'])
df['gill-attachment']=lb.fit_transform(df['gill-attachment'])
df['gill-spacing']=lb.fit_transform(df['gill-spacing'])
df['gill-size']=lb.fit_transform(df['gill-size'])
df['gill-color']=lb.fit_transform(df['gill-color'])
df['stalk-surface-below-ring']=lb.fit_transform(df['stalk-surface-below-ring'])
df['stalk-surface-above-ring']=lb.fit_transform(df['stalk-surface-above-ring'])
df['veil-type']=lb.fit_transform(df['veil-type'])
df['veil-color']=lb.fit_transform(df['veil-color'])
df['ring-number']=lb.fit_transform(df['ring-number'])
df['ring-type']=lb.fit_transform(df['ring-type'])
df['veil-color']=lb.fit_transform(df['veil-color'])
df['veil-color']=lb.fit_transform(df['veil-color'])
df['spore-print-color']=lb.fit_transform(df['spore-print-color'])
df['stalk-color-below-ring']=lb.fit_transform(df['stalk-color-below-ring'])
df['stalk-color-above-ring']=lb.fit_transform(df['stalk-color-above-ring'])
df['habitat']=lb.fit_transform(df['habitat'])
df['stalk-shape']=lb.fit_transform(df['stalk-shape'])
df['stalk-root']=lb.fit_transform(df['stalk-root'])
df['class']=lb.fit_transform(df['class'])
df['population']=lb.fit_transform(df['population'])
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# 2                   1             0          0           5  ...
# 3                   1             0          1           5  ...
# 4                   1             1          0           4  ...
# ...               ...           ...        ...         ...  ...
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            2                       7
# 1                            2                       7
# 2                            2                       7
# 3                            2                       7
# 4                            2                       7
# ...                        ...                     ...
# 8119                         2                       5
# 8120                         2                       5
# 8121                         2                       5
# 8122                         1                       7
# 8123                         2                       5
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          7          0           2            1          4
# 1                          7          0           2            1          4
# 2                          7          0           2            1          4
# 3                          7          0           2            1          4
# 4                          7          0           2            1          0
# ...                      ...        ...         ...          ...        ...
# 8119                       5          0           1            1          4
# 8120                       5          0           0            1          4
# 8121                       5          0           1            1          4
# 8122                       7          0           2            1          0
# 8123                       5          0           1            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 23 columns]

# %%
df1=df.drop(['cap-shape','cap-surface','cap-color','gill-size','gill-spacing','gill-attachment','veil-type','veil-color'],axis=1)
df1
# Out:
#       class  bruises  odor  gill-color  stalk-shape  stalk-root  \
# 0         1        1     6           4            0           3
# 1         0        1     0           4            0           2
# 2         0        1     3           5            0           2
# 3         1        1     6           5            0           3
# 4         0        0     5           4            1           3
# ...     ...      ...   ...         ...          ...         ...
# 8119      0        0     5          11            0           0
# 8120      0        0     5          11            0           0
# 8121      0        0     5           5            0           0
# 8122      1        0     8           0            1           0
# 8123      0        0     5          11            0           0
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 0                            2                         2
# 1                            2                         2
# 2                            2                         2
# 3                            2                         2
# 4                            2                         2
# ...                        ...                       ...
# 8119                         2                         2
# 8120                         2                         2
# 8121                         2                         2
# 8122                         2                         1
# 8123                         2                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  ring-number  ring-type  \
# 0                          7                       7            1          4
# 1                          7                       7            1          4
# 2                          7                       7            1          4
# 3                          7                       7            1          4
# 4                          7                       7            1          0
# ...                      ...                     ...          ...        ...
# 8119                       5                       5            1          4
# 8120                       5                       5            1          4
# 8121                       5                       5            1          4
# 8122                       7                       7            1          0
# 8123                       5                       5            1          4
#
#       spore-print-color  population  habitat
# 0                     2           3        5
# 1                     3           2        1
# 2                     3           2        3
# 3                     2           3        5
# 4                     3           0        1
# ...                 ...         ...      ...
# 8119                  0           1        2
# 8120                  0           4        2
# 8121                  0           1        2
# 8122                  7           4        2
# 8123                  4           1        2
#
# [8124 rows x 15 columns]

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df1.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
df.hist('class')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000BB881E84F0>]],
#       dtype=object)

# %%
x=df1.iloc[:,1:15].values

x
# Out:
# array([[ 1,  6,  4, ...,  2,  3,  5],
#        [ 1,  0,  4, ...,  3,  2,  1],
#        [ 1,  3,  5, ...,  3,  2,  3],
#        ...,
#        [ 0,  5,  5, ...,  0,  1,  2],
#        [ 0,  8,  0, ...,  7,  4,  2],
#        [ 0,  5, 11, ...,  4,  1,  2]])

# %%
y=df1.iloc[:,0].values
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=0)
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (5686, 14) (5686,)
# Test set: (2438, 14) (2438,)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
print("naive bayes")
from sklearn.naive_bayes import GaussianNB


naive_bayes = GaussianNB()


naive_bayes.fit(x_train , y_train)


y_pred = naive_bayes.predict(x_test)
print("accuracy score:", accuracy_score(y_test, y_pred))
print("confustion matrix:\n",confusion_matrix(y_test,y_pred))
print("f1 score:",f1_score(y_test,y_pred,average="micro"))
print("classification report:")
print(classification_report(y_test,y_pred))
# Out:
# naive bayes
# accuracy score: 0.894585726004922
# confustion matrix:
#  [[1220   52]
#  [ 205  961]]
# f1 score: 0.894585726004922
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.90      1272
#            1       0.95      0.82      0.88      1166
#
#     accuracy                           0.89      2438
#    macro avg       0.90      0.89      0.89      2438
# weighted avg       0.90      0.89      0.89      2438

# %%
print("decision tree")
from sklearn.tree import DecisionTreeClassifier
##
tree = DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=5, min_samples_leaf=5)
tree.fit(x_train, y_train)
##
y_pred = tree.predict(x_test)
##
print("f1 score:",f1_score(y_test, y_pred,average="micro"))
print("accuracy score:", accuracy_score(y_test, y_pred))
print("classification report:")
print(classification_report(y_test,y_pred))
print("confusion matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# decision tree
# f1 score: 0.9913863822805579
# accuracy score: 0.9913863822805579
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1272
#            1       1.00      0.98      0.99      1166
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438
#
# confusion matrix:
# [[1269    3]
#  [  18 1148]]

# %%
print("logistic regressio")
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',random_state=100)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print("accuracy score:", accuracy_score(y_test, y_pred))
print("confustion matrix:\n",confusion_matrix(y_test,y_pred))
print("f1 score:",f1_score(y_test,y_pred,average="micro"))
print("classification report:")
print(classification_report(y_test,y_pred))
# Out:
# logistic regressio
# accuracy score: 0.8822805578342904
# confustion matrix:
#  [[1138  134]
#  [ 153 1013]]
# f1 score: 0.8822805578342904
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89      1272
#            1       0.88      0.87      0.88      1166
#
#     accuracy                           0.88      2438
#    macro avg       0.88      0.88      0.88      2438
# weighted avg       0.88      0.88      0.88      2438

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(x_train, y_train)
y_pred=knn_classifier.predict(x_test)
print("f1 score:",f1_score(y_test, y_pred,average="micro"))
print("accuracy score:", accuracy_score(y_test, y_pred))
print("confusion matrix")
print(confusion_matrix(y_test, y_pred))
print("classification report")
print(classification_report(y_test,y_pred))
# Out:
# f1 score: 1.0
# accuracy score: 1.0
# confusion matrix
# [[1272    0]
#  [   0 1166]]
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1272
#            1       1.00      1.00      1.00      1166
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
print("Support Vector Machine")
from sklearn.svm import SVC
classifier = SVC(decision_function_shape='ovo')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print("accuracy score:", accuracy_score(y_test, y_pred))
print("confustion matrix:\n",confusion_matrix(y_test,y_pred))
print("f1 score:",f1_score(y_test,y_pred,average="micro"))
print("classification report:")
print(classification_report(y_test,y_pred))
# Out:
# Support Vector Machine
# accuracy score: 1.0
# confustion matrix:
#  [[1272    0]
#  [   0 1166]]
# f1 score: 1.0
# classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1272
#            1       1.00      1.00      1.00      1166
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
print("Random forest")
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=1000, random_state = 0)
classifier.fit(x_train, y_train)
y_pred=classifier.predict(x_test)

print("f1 score:",f1_score(y_test, y_pred,average="macro"))
print("accuracy score:", accuracy_score(y_test, y_pred))

print("confusion matrix:")
print(confusion_matrix(y_test, y_pred))
print("classification report")
print(classification_report(y_test,y_pred))
# Out:
# Random forest
# f1 score: 1.0
# accuracy score: 1.0
# confusion matrix:
# [[1272    0]
#  [   0 1166]]
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1272
#            1       1.00      1.00      1.00      1166
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
